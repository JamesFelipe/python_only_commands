# %% [markdown]
# # Neste arquivo temos
# * Biblioteca datetime

# %% [markdown]
# # biblioteca datetime
# * serve para tratar de hora e data
# * date.today() -> serve para pegar o dia de hoje(formato: ano/mês/dia)

# %%
from datetime import date
print(date.today())
# Out:
# 2022-12-07
