# %% [markdown]
# # Neste arquivo temos
# * Biblioteca doctest

# %% [markdown]
# # Biblioteca doctest
# * Serve para testar e validar as docstrings
# * doctest.testmod() -> é quem de fato testa se tudo ocorreu bem

# %%
def soma(a, b):
  """
  a: primeiro valor
  b: segundo valor
  c: valor de a + b
  """
  c = a + b
  return c

import doctest
print(doctest.testmod())
# Out:
# TestResults(failed=0, attempted=0)
