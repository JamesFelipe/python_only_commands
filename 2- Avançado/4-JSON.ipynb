# %% [markdown]
# # Neste arquivo temos
# * Json

# %% [markdown]
# # Json(Javascript Object Notation)
# * O módulo padrão chamado json pode pegar hierarquias de dados em Python e convertê-las em representações de strings, esse processo é chamado serialização.
# * Reconstruir os dados estruturados da representação string é chamado desserialização

# %%
# representação Json
import json
x = [1, 'simple', 'list']
print(type(x))
type(json.dumps(x))
# Tudo virtou string
json.dumps(x)
# Out:
# <class 'list'>
# '[1, "simple", "list"]'
