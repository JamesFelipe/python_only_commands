# %% [markdown]
# # Temos nesse documento
# * Zen do python
#   * Poema em inglês
#   * Poema traduzido
# * Implementações
# * Outras
#   * Versão do python
#   * versão do pip
#   * python console
#   * o último valor do console
# * Comentários

# %% [markdown]
# * O zen do python trata da melhor maneira de escrever o código
# * import this -> comando que mostra o zen do python

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# * O Zen de Python, de Tim Peters
#   * Bonito é melhor que feio.
#   * Explícito é melhor que implícito.
#   * Simples é melhor que complexo.
#   * Complexo é melhor do que complicado.
#   * Plano é melhor do que aninhado.
#   * Esparso é melhor do que denso.
#   * A legibilidade conta.
#   * Casos especiais não são especiais o suficiente para quebrar as regras.
#   * Embora a praticidade supere a pureza.
#   * Os erros nunca devem passar silenciosamente.
#   * A menos que explicitamente silenciado.
#   * Diante da ambiguidade, recuse a tentação de adivinhar.
#   * Deve haver uma - e de preferência apenas uma - maneira óbvia de fazer isso.
#   * Embora essa maneira possa não ser óbvia no início, a menos que você seja holandês.
#   * Agora é melhor do que nunca.
#   * Embora nunca seja melhor do que &nbsp; * agora *.
#   * Se a implementação é difícil de explicar, é uma má ideia.
#   * Se a implementação for fácil de explicar, pode ser uma boa ideia.
# Namespaces são uma ótima ideia -- vamos fazer mais desses!

# %% [markdown]
# # Implemetaçoes
# * Python trabalha com uma máquina virtual e compilação em bytecode(CPython)
#
# # Outras
# * Pypy -> python em python, permitindo diversas transpilações em C
# * Transcript - Roda python direto no navegador através de transpilação para javascript

# %%
# verificando a versão do python
# !python --version

# versão do pip
# !pip --version

# abri o console(no colab trava o teclado)
# !python
# Out:
# Python 3.7.15
# pip 21.1.3 from /usr/local/lib/python3.7/dist-packages/pip (python 3.7)

# %%
print(1)
# _(underline sozinho)  pega o último valor do console
# Out:
# 1

# %% [markdown]
# # comentários
# * É a parte do código que não é interpretada, é ideal para explicar algo, use o mínimo possível, pode ser com o sequilha, ou de multiplas linhas com 3 ou 6 aspas
# * Obs.: comentário de múltiplas linhas não existem em python, na realidade, ao usar várias aspas, estamos criando uma string que não foi atribuia a nem um valor

# %%
# comentário simples

"""
Comentário de múltiplas linhas
1
2
3
...
"""
